# %% [markdown]
# # FIT5197 2024 S1 Final Assessment
#
# **SPECIAL NOTE:** Please refer to the [assessment page](https://learning.monash.edu/mod/assign/view.php?id=2017255) for rules, general guidelines and marking rubrics of the assessment (the marking rubric for the kaggle competition part will be released near the deadline in the same page). Failure to comply with the provided information will result in a deduction of mark (e.g., late penalties) or breach of academic integrity.

# %% [markdown]
# **YOUR NAME**: Quoc Khoa Tran
#
# **STUDENT ID**: 34124888
#
# **KAGGLE NAME/ID** (See part 1, Question 5 or part 2, there are penalties if you don't enter it here!!!): Quoc Khoa Tran
#
# Please also enter your details in this [google form](https://forms.gle/isxqfrVnV7ddAj8y8).

# %% [markdown]
# # Part 1 Regression (50 Marks)

# %% [markdown]
# A few thousand people were questioned in a [life and wellbeing survey](https://www.get-happier.com/) to build a model to predict happiness of an individual. You need to build regression models to optimally predict the variable in the survey dataset called 'happiness' based on any, or all, of the other survey question responses.
#
# You have been provided with two datasets, ```regression_train.csv``` and ```regression_test.csv```. Using these datasets, you hope to build a model that can predict happiness level using the other variables. ```regression_train.csv``` comes with the ground-truth target label (i.e. happiness level) whereas `regression_test.csv` comes with independent variables (input information) only.
#
# On the order of around 70 survey questions have been converted into predictor variables that can be used to predict happiness. We do not list all the predictor names here, but their names given in the data header can clearly be linked to the survey questions. e.g., the predictor variable 'iDontFeelParticularlyPleasedWithTheWayIAm' corresponds to the survey question 'I don’t feel particularly pleased with the way I am.'

# %% [markdown]
# **PLEASE NOTE THAT THE USE OF LIBRARIES ARE PROHIBITED IN THESE QUESTIONS UNLESS STATED OTHERWISE, ANSWERS USING LIBRARIES WILL RECEIVE 0 MARKS**

# %% [markdown]
# ## Question 1 (NO LIBRARIES ALLOWED) (4 Mark)
# Please load the ```regression_train.csv``` and fit a [$\textbf{multiple linear regression model}$](https://en.wikipedia.org/wiki/Linear_regression) with 'happiness' being the target variable. According to the summary table, which predictors do you think are possibly associated with the target variable (use the significance level of 0.01), and which are the **Top 5** strongest predictors? Please write an R script to automatically fetch and print this information.
#
# **NOTE**: Manually doing the above tasks will result in 0 marks.

# %%
# ANSWER BLOCK

# Load the data manually without using libraries
train_df <- read.csv("regression_train.csv")

# Fit a multiple linear regression model
model <- lm(happiness ~ ., data = train_df)

# Summarize the model to get the significance of predictors
model_summary <- summary(model)

# Extract the coefficients table
coefficients_table <- model_summary$coefficients

# Identify significant predictors at the 0.01 level
significant_predictors <- coefficients_table[coefficients_table[, "Pr(>|t|)"] < 0.01, ]

# Identify top 5 strongest predictors based on absolute t-value
top_5_predictors <- head(significant_predictors[order(abs(significant_predictors[, "t value"]), decreasing = TRUE), ], 5)

# Print the results
print("Significant predictors at 0.01 level:")
print(significant_predictors)

print("Top 5 strongest predictors:")
print(top_5_predictors)
# Out:
# [1] "Significant predictors at 0.01 level:"
#                                                        Estimate Std. Error
# (Intercept)                                          -22.138272  3.5197268
# income10k - 15k                                        6.268117  1.2386952
# income120k - 150k                                     11.373025  1.2340393
# income150k - 200k                                     11.718396  1.2434310
# income15k - 20k                                       15.447908  1.2809264
# income200k above                                      20.109900  1.3788320
# income20k - 50k                                       20.839607  1.5825100
# income50k - 80k                                       28.546980  1.7382901
# income80k - 120k                                      37.315988  1.6548496
# whatIsYourHeightExpressItAsANumberInMetresM175 - 180   6.104323  2.2061513
# whatIsYourHeightExpressItAsANumberInMetresM180 - 185   7.286107  2.3791630
# alwaysStressed                                        -1.064389  0.3726381
#                                                        t value     Pr(>|t|)
# (Intercept)                                          -6.289770 7.814219e-10
# income10k - 15k                                       5.060258 6.210721e-07
# income120k - 150k                                     9.216096 1.369692e-18
# income150k - 200k                                     9.424243 2.676570e-19
# income15k - 20k                                      12.059949 4.650658e-29
# income200k above                                     14.584735 1.902543e-39
# income20k - 50k                                      13.168704 1.604206e-33
# income50k - 80k                                      16.422449 2.033722e-47
# income80k - 120k                                     22.549474 6.160552e-75
# whatIsYourHeightExpressItAsANumberInMetresM175 - 180  2.766956 5.901767e-03
# whatIsYourHeightExpressItAsANumberInMetresM180 - 185  3.062466 2.332715e-03
# alwaysStressed                                       -2.856361 4.492518e-03
# [1] "Top 5 strongest predictors:"
#                  Estimate Std. Error  t value     Pr(>|t|)
# income80k - 120k 37.31599   1.654850 22.54947 6.160552e-75
# income50k - 80k  28.54698   1.738290 16.42245 2.033722e-47
# income200k above 20.10990   1.378832 14.58474 1.902543e-39
# income20k - 50k  20.83961   1.582510 13.16870 1.604206e-33
# income15k - 20k  15.44791   1.280926 12.05995 4.650658e-29

# %% [markdown]
# ## Question 2 (2 Mark)
# [**R squared**](https://en.wikipedia.org/wiki/Coefficient_of_determination) from the summary table reflects that the full model doesn't fit the training dataset well; thus, you try to quantify the error between the values of the ground-truth and those of the model prediction. You want to write a function to predict 'happiness' with the given dataset and calculate the [root mean squared error (rMSE)](https://en.wikipedia.org/wiki/Root-mean-square_deviation) between the model predictions and the ground truths. Please test this function on the full model and the training dataset.

# %%
# ANSWER BLOCK
# Function to calculate RMSE
calculate_rmse <- function(actual, predicted) {
  sqrt(mean((actual - predicted)^2))
}

# Predict happiness on the training data
predictions <- predict(model, newdata = train_df)

# Calculate RMSE
rmse_full_model <- calculate_rmse(train_df$happiness, predictions)

# Print RMSE
print(rmse_full_model)
# Out:
# [1] 6.672557

# %% [markdown]
# ## Question 3 (2 Marks)
# You find the full model complicated and try to reduce the complexity by performing [bidirectional stepwise regression](https://en.wikipedia.org/wiki/Stepwise_regression) with [BIC](https://en.wikipedia.org/wiki/Bayesian_information_criterion).
#
# Calculate the **rMSE** of this new model with the function that you implemented previously. Is there anything you find unusual? Explain your findings in 100 words.

# %%
# ANSWER BLOCK
# Perform bidirectional stepwise regression using BIC
stepwise_model <- step(model, direction = "both", k = log(nrow(train_df)))

# Predict happiness on the training data using the stepwise model
stepwise_predictions <- predict(stepwise_model, newdata = train_df)

# Calculate RMSE for the stepwise model
rmse_stepwise_model <- calculate_rmse(train_df$happiness, stepwise_predictions)

# Print RMSE for the stepwise model
print(paste("Root Mean Squared Error (rMSE) of Stepwise Model:", rmse_stepwise_model))
# Out:
# Start:  AIC=2326.81
# happiness ~ gender + income + whatIsYourHeightExpressItAsANumberInMetresM +
#     doYouFeelASenseOfPurposeAndMeaningInYourLife104 + howDoYouReconcileSpiritualBeliefsWithScientificOrRationalThinki +
#     howOftenDoYouFeelSociallyConnectedWithYourPeersAndFriends +
#     doYouHaveASupportSystemOfFriendsAndFamilyToTurnToWhenNeeded +
#     howOftenDoYouParticipateInSocialActivitiesIncludingClubsSportsV +
#     doYouFeelComfortableEngagingInConversationsWithPeopleFromDiffer +
#     doYouFeelASenseOfPurposeAndMeaningInYourLife105 + alwaysAnxious +
#     alwaysStressed + alwaysAccountableAndResponsibleForYourActions +
#     alwaysCalm + myBodyIsHypermobileAndLovesToMove + alwaysHaveFun +
#     alwaysSerious + alwaysDepressed + alwaysLoveAndCareForYourself +
#     extremelyGoodAbilityToSense + alwaysHaveDigestiveProblems +
#     iAmIntenselyInterestedInOtherPeople + iRarelyWakeUpFeelingRested +
#     iFindMostThingsAmusing + iAmAlwaysCommittedAndInvolved +
#     iDoNotThinkThatTheWorldIsAGoodPlace + iAmWellSatisfiedAboutEverythingInMyLife +
#     iFindBeautyInSomeThings + iAlwaysHaveACheerfulEffectOnOthers +
#     iFeelThatIAmNotEspeciallyInControlOfMyLife + iUsuallyHaveAGoodInfluenceOnEvents +
#     iDontHaveFunWithOtherPeople + alwaysEngageInPreparingAndUsingYourSkillsAndTalentsInOrderToGai +
#     alwaysMakingProgress + extremelyGoodCommunicator + iDontFeelParticularlyPleasedWithTheWayIAm +
#     iFeelThatLifeIsVeryRewarding + iHaveVeryWarmFeelingsTowardsAlmostEveryone +
#     iAmNotParticularlyOptimisticAboutTheFuture + lifeIsGood +
#     iLaughALot + iDontThinkILookAttractive
#
#                                                                   Df Sum of Sq
# - whatIsYourHeightExpressItAsANumberInMetresM                      9       910
# - howOftenDoYouParticipateInSocialActivitiesIncludingClubsSportsV  4       103
# - doYouHaveASupportSystemOfFriendsAndFamilyToTurnToWhenNeeded      3        77
# - howOftenDoYouFeelSociallyConnectedWithYourPeersAndFriends        3       200
# - gender                                                           2        18
# - doYouFeelComfortableEngagingInConversationsWithPeopleFromDiffer  3       318
# - howDoYouReconcileSpiritualBeliefsWithScientificOrRationalThinki  2       138
# - iHaveVeryWarmFeelingsTowardsAlmostEveryone                       1         2
# - iAmNotParticularlyOptimisticAboutTheFuture                       1         6
# - alwaysEngageInPreparingAndUsingYourSkillsAndTalentsInOrderToGai  1         6
# - iFindBeautyInSomeThings                                          1        12
# - iAmIntenselyInterestedInOtherPeople                              1        12
# - extremelyGoodAbilityToSense                                      1        12
# - alwaysLoveAndCareForYourself                                     1        14
# - iDontHaveFunWithOtherPeople                                      1        18
# - doYouFeelASenseOfPurposeAndMeaningInYourLife105                  1        21
# - myBodyIsHypermobileAndLovesToMove                                1        23
# - iFeelThatLifeIsVeryRewarding                                     1        25
# - alwaysHaveDigestiveProblems                                      1        27
# - iAmWellSatisfiedAboutEverythingInMyLife                          1        39
# - iDontFeelParticularlyPleasedWithTheWayIAm                        1        44
# - alwaysCalm                                                       1        51
# - alwaysMakingProgress                                             1        51
# - iFeelThatIAmNotEspeciallyInControlOfMyLife                       1        51
# - lifeIsGood                                                       1        66
# - extremelyGoodCommunicator                                        1        67
# - alwaysDepressed                                                  1        80
# - iRarelyWakeUpFeelingRested                                       1        84
# - alwaysSerious                                                    1       106
# - alwaysAccountableAndResponsibleForYourActions                    1       108
# - iUsuallyHaveAGoodInfluenceOnEvents                               1       112
# - alwaysHaveFun                                                    1       112
# - iDontThinkILookAttractive                                        1       120
# - iFindMostThingsAmusing                                           1       143
# - doYouFeelASenseOfPurposeAndMeaningInYourLife104                  1       176
# - iDoNotThinkThatTheWorldIsAGoodPlace                              1       179
# - alwaysAnxious                                                    1       195
# <none>
# - iAlwaysHaveACheerfulEffectOnOthers                               1       300
# - iLaughALot                                                       1       312
# - iAmAlwaysCommittedAndInvolved                                    1       328
# - alwaysStressed                                                   1       421
# - income                                                           8     40664
#                                                                     RSS    AIC
# - whatIsYourHeightExpressItAsANumberInMetresM                     23171 2290.9
# - howOftenDoYouParticipateInSocialActivitiesIncludingClubsSportsV 22364 2304.3
# - doYouHaveASupportSystemOfFriendsAndFamilyToTurnToWhenNeeded     22339 2309.9
# - howOftenDoYouFeelSociallyConnectedWithYourPeersAndFriends       22461 2312.6
# - gender                                                          22279 2314.8
# - doYouFeelComfortableEngagingInConversationsWithPeopleFromDiffer 22580 2315.3
# - howDoYouReconcileSpiritualBeliefsWithScientificOrRationalThinki 22399 2317.5
# - iHaveVeryWarmFeelingsTowardsAlmostEveryone                      22264 2320.7
# - iAmNotParticularlyOptimisticAboutTheFuture                      22267 2320.7
# - alwaysEngageInPreparingAndUsingYourSkillsAndTalentsInOrderToGai 22268 2320.7
# - iFindBeautyInSomeThings                                         22273 2320.9
# - iAmIntenselyInterestedInOtherPeople                             22273 2320.9
# - extremelyGoodAbilityToSense                                     22274 2320.9
# - alwaysLoveAndCareForYourself                                    22276 2320.9
# - iDontHaveFunWithOtherPeople                                     22279 2321.0
# - doYouFeelASenseOfPurposeAndMeaningInYourLife105                 22282 2321.1
# - myBodyIsHypermobileAndLovesToMove                               22285 2321.1
# - iFeelThatLifeIsVeryRewarding                                    22286 2321.2
# - alwaysHaveDigestiveProblems                                     22288 2321.2
# - iAmWellSatisfiedAboutEverythingInMyLife                         22301 2321.5
# - iDontFeelParticularlyPleasedWithTheWayIAm                       22306 2321.6
# - alwaysCalm                                                      22312 2321.7
# - alwaysMakingProgress                                            22313 2321.8
# - iFeelThatIAmNotEspeciallyInControlOfMyLife                      22313 2321.8
# - lifeIsGood                                                      22328 2322.1
# - extremelyGoodCommunicator                                       22328 2322.1
# - alwaysDepressed                                                 22342 2322.4
# - iRarelyWakeUpFeelingRested                                      22345 2322.5
# - alwaysSerious                                                   22367 2323.0
# - alwaysAccountableAndResponsibleForYourActions                   22369 2323.0
# - iUsuallyHaveAGoodInfluenceOnEvents                              22373 2323.1
# - alwaysHaveFun                                                   22373 2323.1
# - iDontThinkILookAttractive                                       22382 2323.3
# - iFindMostThingsAmusing                                          22404 2323.8
# - doYouFeelASenseOfPurposeAndMeaningInYourLife104                 22437 2324.5
# - iDoNotThinkThatTheWorldIsAGoodPlace                             22441 2324.6
# - alwaysAnxious                                                   22456 2324.9
# <none>                                                            22262 2326.8
# - iAlwaysHaveACheerfulEffectOnOthers                              22562 2327.3
# - iLaughALot                                                      22573 2327.6
# - iAmAlwaysCommittedAndInvolved                                   22589 2327.9
# - alwaysStressed                                                  22683 2330.0
# - income                                                          62925 2796.6
#
# Step:  AIC=2290.91
# happiness ~ gender + income + doYouFeelASenseOfPurposeAndMeaningInYourLife104 +
#     howDoYouReconcileSpiritualBeliefsWithScientificOrRationalThinki +
#     howOftenDoYouFeelSociallyConnectedWithYourPeersAndFriends +
#     doYouHaveASupportSystemOfFriendsAndFamilyToTurnToWhenNeeded +
#     howOftenDoYouParticipateInSocialActivitiesIncludingClubsSportsV +
#     doYouFeelComfortableEngagingInConversationsWithPeopleFromDiffer +
#     doYouFeelASenseOfPurposeAndMeaningInYourLife105 + alwaysAnxious +
#     alwaysStressed + alwaysAccountableAndResponsibleForYourActions +
#     alwaysCalm + myBodyIsHypermobileAndLovesToMove + alwaysHaveFun +
#     alwaysSerious + alwaysDepressed + alwaysLoveAndCareForYourself +
#     extremelyGoodAbilityToSense + alwaysHaveDigestiveProblems +
#     iAmIntenselyInterestedInOtherPeople + iRarelyWakeUpFeelingRested +
#     iFindMostThingsAmusing + iAmAlwaysCommittedAndInvolved +
#     iDoNotThinkThatTheWorldIsAGoodPlace + iAmWellSatisfiedAboutEverythingInMyLife +
#     iFindBeautyInSomeThings + iAlwaysHaveACheerfulEffectOnOthers +
#     iFeelThatIAmNotEspeciallyInControlOfMyLife + iUsuallyHaveAGoodInfluenceOnEvents +
#     iDontHaveFunWithOtherPeople + alwaysEngageInPreparingAndUsingYourSkillsAndTalentsInOrderToGai +
#     alwaysMakingProgress + extremelyGoodCommunicator + iDontFeelParticularlyPleasedWithTheWayIAm +
#     iFeelThatLifeIsVeryRewarding + iHaveVeryWarmFeelingsTowardsAlmostEveryone +
#     iAmNotParticularlyOptimisticAboutTheFuture + lifeIsGood +
#     iLaughALot + iDontThinkILookAttractive
#
#                                                                   Df Sum of Sq
# - howOftenDoYouParticipateInSocialActivitiesIncludingClubsSportsV  4       118
# - doYouHaveASupportSystemOfFriendsAndFamilyToTurnToWhenNeeded      3       130
# - howOftenDoYouFeelSociallyConnectedWithYourPeersAndFriends        3       229
# - doYouFeelComfortableEngagingInConversationsWithPeopleFromDiffer  3       379
# - howDoYouReconcileSpiritualBeliefsWithScientificOrRationalThinki  2       137
# - gender                                                           2       158
# - iHaveVeryWarmFeelingsTowardsAlmostEveryone                       1         0
# - iAmNotParticularlyOptimisticAboutTheFuture                       1         1
# - alwaysEngageInPreparingAndUsingYourSkillsAndTalentsInOrderToGai  1         3
# - iAmIntenselyInterestedInOtherPeople                              1         4
# - iFeelThatLifeIsVeryRewarding                                     1         9
# - alwaysLoveAndCareForYourself                                     1        11
# - iDontHaveFunWithOtherPeople                                      1        12
# - myBodyIsHypermobileAndLovesToMove                                1        28
# - doYouFeelASenseOfPurposeAndMeaningInYourLife105                  1        31
# - iFindBeautyInSomeThings                                          1        33
# - alwaysHaveDigestiveProblems                                      1        36
# - lifeIsGood                                                       1        40
# - extremelyGoodAbilityToSense                                      1        46
# - alwaysDepressed                                                  1        53
# - iAmWellSatisfiedAboutEverythingInMyLife                          1        57
# - iFeelThatIAmNotEspeciallyInControlOfMyLife                       1        70
# - extremelyGoodCommunicator                                        1        76
# - iRarelyWakeUpFeelingRested                                       1        77
# - iDoNotThinkThatTheWorldIsAGoodPlace                              1        88
# - iDontFeelParticularlyPleasedWithTheWayIAm                        1        90
# - iDontThinkILookAttractive                                        1        92
# - alwaysCalm                                                       1       103
# - alwaysAnxious                                                    1       154
# - alwaysMakingProgress                                             1       169
# - iUsuallyHaveAGoodInfluenceOnEvents                               1       175
# - iFindMostThingsAmusing                                           1       177
# - alwaysSerious                                                    1       179
# - alwaysHaveFun                                                    1       214
# - iAlwaysHaveACheerfulEffectOnOthers                               1       234
# - doYouFeelASenseOfPurposeAndMeaningInYourLife104                  1       237
# - alwaysAccountableAndResponsibleForYourActions                    1       250
# <none>
# - iLaughALot                                                       1       291
# - alwaysStressed                                                   1       373
# - iAmAlwaysCommittedAndInvolved                                    1       469
# + whatIsYourHeightExpressItAsANumberInMetresM                      9       910
# - income                                                           8     40733
#                                                                     RSS    AIC
# - howOftenDoYouParticipateInSocialActivitiesIncludingClubsSportsV 23289 2268.6
# - doYouHaveASupportSystemOfFriendsAndFamilyToTurnToWhenNeeded     23301 2275.1
# - howOftenDoYouFeelSociallyConnectedWithYourPeersAndFriends       23401 2277.2
# - doYouFeelComfortableEngagingInConversationsWithPeopleFromDiffer 23550 2280.4
# - howDoYouReconcileSpiritualBeliefsWithScientificOrRationalThinki 23309 2281.4
# - gender                                                          23330 2281.9
# - iHaveVeryWarmFeelingsTowardsAlmostEveryone                      23172 2284.7
# - iAmNotParticularlyOptimisticAboutTheFuture                      23172 2284.7
# - alwaysEngageInPreparingAndUsingYourSkillsAndTalentsInOrderToGai 23174 2284.8
# - iAmIntenselyInterestedInOtherPeople                             23176 2284.8
# - iFeelThatLifeIsVeryRewarding                                    23181 2284.9
# - alwaysLoveAndCareForYourself                                    23183 2284.9
# - iDontHaveFunWithOtherPeople                                     23184 2285.0
# - myBodyIsHypermobileAndLovesToMove                               23199 2285.3
# - doYouFeelASenseOfPurposeAndMeaningInYourLife105                 23203 2285.4
# - iFindBeautyInSomeThings                                         23205 2285.4
# - alwaysHaveDigestiveProblems                                     23207 2285.5
# - lifeIsGood                                                      23212 2285.6
# - extremelyGoodAbilityToSense                                     23218 2285.7
# - alwaysDepressed                                                 23224 2285.8
# - iAmWellSatisfiedAboutEverythingInMyLife                         23228 2285.9
# - iFeelThatIAmNotEspeciallyInControlOfMyLife                      23242 2286.2
# - extremelyGoodCommunicator                                       23247 2286.3
# - iRarelyWakeUpFeelingRested                                      23249 2286.4
# - iDoNotThinkThatTheWorldIsAGoodPlace                             23259 2286.6
# - iDontFeelParticularlyPleasedWithTheWayIAm                       23262 2286.6
# - iDontThinkILookAttractive                                       23263 2286.7
# - alwaysCalm                                                      23274 2286.9
# - alwaysAnxious                                                   23325 2288.0
# - alwaysMakingProgress                                            23341 2288.3
# - iUsuallyHaveAGoodInfluenceOnEvents                              23347 2288.5
# - iFindMostThingsAmusing                                          23349 2288.5
# - alwaysSerious                                                   23350 2288.5
# - alwaysHaveFun                                                   23386 2289.3
# - iAlwaysHaveACheerfulEffectOnOthers                              23405 2289.7
# - doYouFeelASenseOfPurposeAndMeaningInYourLife104                 23408 2289.8
# - alwaysAccountableAndResponsibleForYourActions                   23422 2290.1
# <none>                                                            23171 2290.9
# - iLaughALot                                                      23462 2290.9
# - alwaysStressed                                                  23544 2292.7
# - iAmAlwaysCommittedAndInvolved                                   23640 2294.7
# + whatIsYourHeightExpressItAsANumberInMetresM                     22262 2326.8
# - income                                                          63904 2748.4
#
# Step:  AIC=2268.59
# happiness ~ gender + income + doYouFeelASenseOfPurposeAndMeaningInYourLife104 +
#     howDoYouReconcileSpiritualBeliefsWithScientificOrRationalThinki +
#     howOftenDoYouFeelSociallyConnectedWithYourPeersAndFriends +
#     doYouHaveASupportSystemOfFriendsAndFamilyToTurnToWhenNeeded +
#     doYouFeelComfortableEngagingInConversationsWithPeopleFromDiffer +
#     doYouFeelASenseOfPurposeAndMeaningInYourLife105 + alwaysAnxious +
#     alwaysStressed + alwaysAccountableAndResponsibleForYourActions +
#     alwaysCalm + myBodyIsHypermobileAndLovesToMove + alwaysHaveFun +
#     alwaysSerious + alwaysDepressed + alwaysLoveAndCareForYourself +
#     extremelyGoodAbilityToSense + alwaysHaveDigestiveProblems +
#     iAmIntenselyInterestedInOtherPeople + iRarelyWakeUpFeelingRested +
#     iFindMostThingsAmusing + iAmAlwaysCommittedAndInvolved +
#     iDoNotThinkThatTheWorldIsAGoodPlace + iAmWellSatisfiedAboutEverythingInMyLife +
#     iFindBeautyInSomeThings + iAlwaysHaveACheerfulEffectOnOthers +
#     iFeelThatIAmNotEspeciallyInControlOfMyLife + iUsuallyHaveAGoodInfluenceOnEvents +
#     iDontHaveFunWithOtherPeople + alwaysEngageInPreparingAndUsingYourSkillsAndTalentsInOrderToGai +
#     alwaysMakingProgress + extremelyGoodCommunicator + iDontFeelParticularlyPleasedWithTheWayIAm +
#     iFeelThatLifeIsVeryRewarding + iHaveVeryWarmFeelingsTowardsAlmostEveryone +
#     iAmNotParticularlyOptimisticAboutTheFuture + lifeIsGood +
#     iLaughALot + iDontThinkILookAttractive
#
#                                                                   Df Sum of Sq
# - doYouHaveASupportSystemOfFriendsAndFamilyToTurnToWhenNeeded      3       164
# - howOftenDoYouFeelSociallyConnectedWithYourPeersAndFriends        3       213
# - doYouFeelComfortableEngagingInConversationsWithPeopleFromDiffer  3       425
# - howDoYouReconcileSpiritualBeliefsWithScientificOrRationalThinki  2       144
# - gender                                                           2       200
# - iAmNotParticularlyOptimisticAboutTheFuture                       1         0
# - iHaveVeryWarmFeelingsTowardsAlmostEveryone                       1         0
# - iAmIntenselyInterestedInOtherPeople                              1         2
# - alwaysEngageInPreparingAndUsingYourSkillsAndTalentsInOrderToGai  1         4
# - iFeelThatLifeIsVeryRewarding                                     1         4
# - iDontHaveFunWithOtherPeople                                      1         6
# - alwaysLoveAndCareForYourself                                     1        11
# - myBodyIsHypermobileAndLovesToMove                                1        19
# - iFindBeautyInSomeThings                                          1        22
# - doYouFeelASenseOfPurposeAndMeaningInYourLife105                  1        22
# - alwaysHaveDigestiveProblems                                      1        29
# - alwaysDepressed                                                  1        40
# - lifeIsGood                                                       1        46
# - iFeelThatIAmNotEspeciallyInControlOfMyLife                       1        47
# - iAmWellSatisfiedAboutEverythingInMyLife                          1        51
# - extremelyGoodAbilityToSense                                      1        58
# - iRarelyWakeUpFeelingRested                                       1        76
# - extremelyGoodCommunicator                                        1        76
# - iDontFeelParticularlyPleasedWithTheWayIAm                        1        77
# - alwaysCalm                                                       1        93
# - iDontThinkILookAttractive                                        1        94
# - iDoNotThinkThatTheWorldIsAGoodPlace                              1       105
# - iFindMostThingsAmusing                                           1       150
# - alwaysMakingProgress                                             1       168
# - iUsuallyHaveAGoodInfluenceOnEvents                               1       175
# - alwaysAnxious                                                    1       185
# - iAlwaysHaveACheerfulEffectOnOthers                               1       213
# - alwaysSerious                                                    1       224
# - doYouFeelASenseOfPurposeAndMeaningInYourLife104                  1       228
# - alwaysHaveFun                                                    1       228
# - alwaysAccountableAndResponsibleForYourActions                    1       270
# <none>
# - iLaughALot                                                       1       302
# - alwaysStressed                                                   1       352
# - iAmAlwaysCommittedAndInvolved                                    1       441
# + howOftenDoYouParticipateInSocialActivitiesIncludingClubsSportsV  4       118
# + whatIsYourHeightExpressItAsANumberInMetresM                      9       925
# - income                                                           8     41480
#                                                                     RSS    AIC
# - doYouHaveASupportSystemOfFriendsAndFamilyToTurnToWhenNeeded     23453 2253.4
# - howOftenDoYouFeelSociallyConnectedWithYourPeersAndFriends       23502 2254.5
# - doYouFeelComfortableEngagingInConversationsWithPeopleFromDiffer 23714 2259.0
# - howDoYouReconcileSpiritualBeliefsWithScientificOrRationalThinki 23434 2259.2
# - gender                                                          23490 2260.4
# - iAmNotParticularlyOptimisticAboutTheFuture                      23290 2262.4
# - iHaveVeryWarmFeelingsTowardsAlmostEveryone                      23290 2262.4
# - iAmIntenselyInterestedInOtherPeople                             23292 2262.4
# - alwaysEngageInPreparingAndUsingYourSkillsAndTalentsInOrderToGai 23294 2262.5
# - iFeelThatLifeIsVeryRewarding                                    23294 2262.5
# - iDontHaveFunWithOtherPeople                                     23295 2262.5
# - alwaysLoveAndCareForYourself                                    23300 2262.6
# - myBodyIsHypermobileAndLovesToMove                               23309 2262.8
# - iFindBeautyInSomeThings                                         23311 2262.8
# - doYouFeelASenseOfPurposeAndMeaningInYourLife105                 23312 2262.8
# - alwaysHaveDigestiveProblems                                     23319 2263.0
# - alwaysDepressed                                                 23330 2263.2
# - lifeIsGood                                                      23335 2263.4
# - iFeelThatIAmNotEspeciallyInControlOfMyLife                      23337 2263.4
# - iAmWellSatisfiedAboutEverythingInMyLife                         23341 2263.5
# - extremelyGoodAbilityToSense                                     23347 2263.6
# - iRarelyWakeUpFeelingRested                                      23365 2264.0
# - extremelyGoodCommunicator                                       23366 2264.0
# - iDontFeelParticularlyPleasedWithTheWayIAm                       23367 2264.0
# - alwaysCalm                                                      23383 2264.4
# - iDontThinkILookAttractive                                       23384 2264.4
# - iDoNotThinkThatTheWorldIsAGoodPlace                             23394 2264.6
# - iFindMostThingsAmusing                                          23440 2265.6
# - alwaysMakingProgress                                            23458 2266.0
# - iUsuallyHaveAGoodInfluenceOnEvents                              23465 2266.1
# - alwaysAnxious                                                   23474 2266.3
# - iAlwaysHaveACheerfulEffectOnOthers                              23502 2266.9
# - alwaysSerious                                                   23513 2267.2
# - doYouFeelASenseOfPurposeAndMeaningInYourLife104                 23517 2267.2
# - alwaysHaveFun                                                   23518 2267.3
# - alwaysAccountableAndResponsibleForYourActions                   23560 2268.1
# <none>                                                            23289 2268.6
# - iLaughALot                                                      23592 2268.8
# - alwaysStressed                                                  23642 2269.9
# - iAmAlwaysCommittedAndInvolved                                   23731 2271.8
# + howOftenDoYouParticipateInSocialActivitiesIncludingClubsSportsV 23171 2290.9
# + whatIsYourHeightExpressItAsANumberInMetresM                     22364 2304.3
# - income                                                          64769 2730.3
#
# Step:  AIC=2253.45
# happiness ~ gender + income + doYouFeelASenseOfPurposeAndMeaningInYourLife104 +
#     howDoYouReconcileSpiritualBeliefsWithScientificOrRationalThinki +
#     howOftenDoYouFeelSociallyConnectedWithYourPeersAndFriends +
#     doYouFeelComfortableEngagingInConversationsWithPeopleFromDiffer +
#     doYouFeelASenseOfPurposeAndMeaningInYourLife105 + alwaysAnxious +
#     alwaysStressed + alwaysAccountableAndResponsibleForYourActions +
#     alwaysCalm + myBodyIsHypermobileAndLovesToMove + alwaysHaveFun +
#     alwaysSerious + alwaysDepressed + alwaysLoveAndCareForYourself +
#     extremelyGoodAbilityToSense + alwaysHaveDigestiveProblems +
#     iAmIntenselyInterestedInOtherPeople + iRarelyWakeUpFeelingRested +
#     iFindMostThingsAmusing + iAmAlwaysCommittedAndInvolved +
#     iDoNotThinkThatTheWorldIsAGoodPlace + iAmWellSatisfiedAboutEverythingInMyLife +
#     iFindBeautyInSomeThings + iAlwaysHaveACheerfulEffectOnOthers +
#     iFeelThatIAmNotEspeciallyInControlOfMyLife + iUsuallyHaveAGoodInfluenceOnEvents +
#     iDontHaveFunWithOtherPeople + alwaysEngageInPreparingAndUsingYourSkillsAndTalentsInOrderToGai +
#     alwaysMakingProgress + extremelyGoodCommunicator + iDontFeelParticularlyPleasedWithTheWayIAm +
#     iFeelThatLifeIsVeryRewarding + iHaveVeryWarmFeelingsTowardsAlmostEveryone +
#     iAmNotParticularlyOptimisticAboutTheFuture + lifeIsGood +
#     iLaughALot + iDontThinkILookAttractive
#
#                                                                   Df Sum of Sq
# - howOftenDoYouFeelSociallyConnectedWithYourPeersAndFriends        3       234
# - howDoYouReconcileSpiritualBeliefsWithScientificOrRationalThinki  2       110
# - doYouFeelComfortableEngagingInConversationsWithPeopleFromDiffer  3       420
# - gender                                                           2       181
# - iHaveVeryWarmFeelingsTowardsAlmostEveryone                       1         0
# - iAmNotParticularlyOptimisticAboutTheFuture                       1         0
# - iDontHaveFunWithOtherPeople                                      1         2
# - iFeelThatLifeIsVeryRewarding                                     1         3
# - alwaysEngageInPreparingAndUsingYourSkillsAndTalentsInOrderToGai  1         5
# - iAmIntenselyInterestedInOtherPeople                              1        11
# - myBodyIsHypermobileAndLovesToMove                                1        12
# - alwaysHaveDigestiveProblems                                      1        18
# - alwaysLoveAndCareForYourself                                     1        19
# - iFindBeautyInSomeThings                                          1        27
# - iFeelThatIAmNotEspeciallyInControlOfMyLife                       1        31
# - alwaysDepressed                                                  1        39
# - doYouFeelASenseOfPurposeAndMeaningInYourLife105                  1        41
# - extremelyGoodAbilityToSense                                      1        50
# - lifeIsGood                                                       1        53
# - iAmWellSatisfiedAboutEverythingInMyLife                          1        65
# - iRarelyWakeUpFeelingRested                                       1        75
# - extremelyGoodCommunicator                                        1        78
# - iDoNotThinkThatTheWorldIsAGoodPlace                              1        85
# - iDontThinkILookAttractive                                        1        93
# - alwaysCalm                                                       1        98
# - iDontFeelParticularlyPleasedWithTheWayIAm                        1        99
# - iUsuallyHaveAGoodInfluenceOnEvents                               1       150
# - alwaysMakingProgress                                             1       166
# - alwaysAnxious                                                    1       189
# - iFindMostThingsAmusing                                           1       196
# - alwaysHaveFun                                                    1       204
# - doYouFeelASenseOfPurposeAndMeaningInYourLife104                  1       219
# - alwaysSerious                                                    1       231
# - alwaysAccountableAndResponsibleForYourActions                    1       254
# - iLaughALot                                                       1       256
# - iAlwaysHaveACheerfulEffectOnOthers                               1       278
# <none>
# - alwaysStressed                                                   1       363
# - iAmAlwaysCommittedAndInvolved                                    1       511
# + doYouHaveASupportSystemOfFriendsAndFamilyToTurnToWhenNeeded      3       164
# + howOftenDoYouParticipateInSocialActivitiesIncludingClubsSportsV  4       152
# + whatIsYourHeightExpressItAsANumberInMetresM                      9       991
# - income                                                           8     42726
#                                                                     RSS    AIC
# - howOftenDoYouFeelSociallyConnectedWithYourPeersAndFriends       23687 2239.8
# - howDoYouReconcileSpiritualBeliefsWithScientificOrRationalThinki 23564 2243.4
# - doYouFeelComfortableEngagingInConversationsWithPeopleFromDiffer 23873 2243.7
# - gender                                                          23635 2244.9
# - iHaveVeryWarmFeelingsTowardsAlmostEveryone                      23453 2247.2
# - iAmNotParticularlyOptimisticAboutTheFuture                      23454 2247.2
# - iDontHaveFunWithOtherPeople                                     23455 2247.3
# - iFeelThatLifeIsVeryRewarding                                    23456 2247.3
# - alwaysEngageInPreparingAndUsingYourSkillsAndTalentsInOrderToGai 23458 2247.3
# - iAmIntenselyInterestedInOtherPeople                             23465 2247.5
# - myBodyIsHypermobileAndLovesToMove                               23465 2247.5
# - alwaysHaveDigestiveProblems                                     23471 2247.6
# - alwaysLoveAndCareForYourself                                    23472 2247.6
# - iFindBeautyInSomeThings                                         23480 2247.8
# - iFeelThatIAmNotEspeciallyInControlOfMyLife                      23484 2247.9
# - alwaysDepressed                                                 23492 2248.1
# - doYouFeelASenseOfPurposeAndMeaningInYourLife105                 23494 2248.1
# - extremelyGoodAbilityToSense                                     23503 2248.3
# - lifeIsGood                                                      23506 2248.4
# - iAmWellSatisfiedAboutEverythingInMyLife                         23519 2248.6
# - iRarelyWakeUpFeelingRested                                      23529 2248.8
# - extremelyGoodCommunicator                                       23532 2248.9
# - iDoNotThinkThatTheWorldIsAGoodPlace                             23538 2249.1
# - iDontThinkILookAttractive                                       23547 2249.2
# - alwaysCalm                                                      23551 2249.3
# - iDontFeelParticularlyPleasedWithTheWayIAm                       23553 2249.3
# - iUsuallyHaveAGoodInfluenceOnEvents                              23603 2250.4
# - alwaysMakingProgress                                            23620 2250.8
# - alwaysAnxious                                                   23643 2251.3
# - iFindMostThingsAmusing                                          23649 2251.4
# - alwaysHaveFun                                                   23657 2251.6
# - doYouFeelASenseOfPurposeAndMeaningInYourLife104                 23673 2251.9
# - alwaysSerious                                                   23685 2252.2
# - alwaysAccountableAndResponsibleForYourActions                   23708 2252.6
# - iLaughALot                                                      23709 2252.7
# - iAlwaysHaveACheerfulEffectOnOthers                              23731 2253.1
# <none>                                                            23453 2253.4
# - alwaysStressed                                                  23816 2254.9
# - iAmAlwaysCommittedAndInvolved                                   23965 2258.0
# + doYouHaveASupportSystemOfFriendsAndFamilyToTurnToWhenNeeded     23289 2268.6
# + howOftenDoYouParticipateInSocialActivitiesIncludingClubsSportsV 23301 2275.1
# + whatIsYourHeightExpressItAsANumberInMetresM                     22462 2287.8
# - income                                                          66179 2722.4
#
# Step:  AIC=2239.78
# happiness ~ gender + income + doYouFeelASenseOfPurposeAndMeaningInYourLife104 +
#     howDoYouReconcileSpiritualBeliefsWithScientificOrRationalThinki +
#     doYouFeelComfortableEngagingInConversationsWithPeopleFromDiffer +
#     doYouFeelASenseOfPurposeAndMeaningInYourLife105 + alwaysAnxious +
#     alwaysStressed + alwaysAccountableAndResponsibleForYourActions +
#     alwaysCalm + myBodyIsHypermobileAndLovesToMove + alwaysHaveFun +
#     alwaysSerious + alwaysDepressed + alwaysLoveAndCareForYourself +
#     extremelyGoodAbilityToSense + alwaysHaveDigestiveProblems +
#     iAmIntenselyInterestedInOtherPeople + iRarelyWakeUpFeelingRested +
#     iFindMostThingsAmusing + iAmAlwaysCommittedAndInvolved +
#     iDoNotThinkThatTheWorldIsAGoodPlace + iAmWellSatisfiedAboutEverythingInMyLife +
#     iFindBeautyInSomeThings + iAlwaysHaveACheerfulEffectOnOthers +
#     iFeelThatIAmNotEspeciallyInControlOfMyLife + iUsuallyHaveAGoodInfluenceOnEvents +
#     iDontHaveFunWithOtherPeople + alwaysEngageInPreparingAndUsingYourSkillsAndTalentsInOrderToGai +
#     alwaysMakingProgress + extremelyGoodCommunicator + iDontFeelParticularlyPleasedWithTheWayIAm +
#     iFeelThatLifeIsVeryRewarding + iHaveVeryWarmFeelingsTowardsAlmostEveryone +
#     iAmNotParticularlyOptimisticAboutTheFuture + lifeIsGood +
#     iLaughALot + iDontThinkILookAttractive
#
#                                                                   Df Sum of Sq
# - howDoYouReconcileSpiritualBeliefsWithScientificOrRationalThinki  2       110
# - gender                                                           2       192
# - doYouFeelComfortableEngagingInConversationsWithPeopleFromDiffer  3       499
# - iAmNotParticularlyOptimisticAboutTheFuture                       1         0
# - iFeelThatLifeIsVeryRewarding                                     1         0
# - iHaveVeryWarmFeelingsTowardsAlmostEveryone                       1         2
# - iDontHaveFunWithOtherPeople                                      1         3
# - alwaysEngageInPreparingAndUsingYourSkillsAndTalentsInOrderToGai  1         6
# - myBodyIsHypermobileAndLovesToMove                                1         7
# - iAmIntenselyInterestedInOtherPeople                              1        11
# - alwaysHaveDigestiveProblems                                      1        11
# - iFeelThatIAmNotEspeciallyInControlOfMyLife                       1        18
# - alwaysLoveAndCareForYourself                                     1        20
# - iFindBeautyInSomeThings                                          1        26
# - alwaysDepressed                                                  1        35
# - lifeIsGood                                                       1        40
# - doYouFeelASenseOfPurposeAndMeaningInYourLife105                  1        56
# - extremelyGoodAbilityToSense                                      1        71
# - iDoNotThinkThatTheWorldIsAGoodPlace                              1        72
# - iDontFeelParticularlyPleasedWithTheWayIAm                        1        82
# - iAmWellSatisfiedAboutEverythingInMyLife                          1        92
# - alwaysCalm                                                       1        92
# - iRarelyWakeUpFeelingRested                                       1        93
# - extremelyGoodCommunicator                                        1        95
# - iDontThinkILookAttractive                                        1       112
# - iUsuallyHaveAGoodInfluenceOnEvents                               1       160
# - alwaysMakingProgress                                             1       177
# - alwaysAnxious                                                    1       184
# - alwaysHaveFun                                                    1       191
# - doYouFeelASenseOfPurposeAndMeaningInYourLife104                  1       213
# - alwaysSerious                                                    1       216
# - iFindMostThingsAmusing                                           1       240
# - alwaysAccountableAndResponsibleForYourActions                    1       266
# - iLaughALot                                                       1       275
# - iAlwaysHaveACheerfulEffectOnOthers                               1       283
# <none>
# - alwaysStressed                                                   1       417
# - iAmAlwaysCommittedAndInvolved                                    1       460
# + howOftenDoYouFeelSociallyConnectedWithYourPeersAndFriends        3       234
# + doYouHaveASupportSystemOfFriendsAndFamilyToTurnToWhenNeeded      3       185
# + howOftenDoYouParticipateInSocialActivitiesIncludingClubsSportsV  4       134
# + whatIsYourHeightExpressItAsANumberInMetresM                      9      1017
# - income                                                           8     42973
#                                                                     RSS    AIC
# - howDoYouReconcileSpiritualBeliefsWithScientificOrRationalThinki 23798 2229.7
# - gender                                                          23880 2231.4
# - doYouFeelComfortableEngagingInConversationsWithPeopleFromDiffer 24186 2231.6
# - iAmNotParticularlyOptimisticAboutTheFuture                      23688 2233.6
# - iFeelThatLifeIsVeryRewarding                                    23688 2233.6
# - iHaveVeryWarmFeelingsTowardsAlmostEveryone                      23689 2233.6
# - iDontHaveFunWithOtherPeople                                     23690 2233.6
# - alwaysEngageInPreparingAndUsingYourSkillsAndTalentsInOrderToGai 23693 2233.7
# - myBodyIsHypermobileAndLovesToMove                               23695 2233.7
# - iAmIntenselyInterestedInOtherPeople                             23698 2233.8
# - alwaysHaveDigestiveProblems                                     23698 2233.8
# - iFeelThatIAmNotEspeciallyInControlOfMyLife                      23705 2233.9
# - alwaysLoveAndCareForYourself                                    23707 2234.0
# - iFindBeautyInSomeThings                                         23713 2234.1
# - alwaysDepressed                                                 23722 2234.3
# - lifeIsGood                                                      23727 2234.4
# - doYouFeelASenseOfPurposeAndMeaningInYourLife105                 23743 2234.7
# - extremelyGoodAbilityToSense                                     23758 2235.1
# - iDoNotThinkThatTheWorldIsAGoodPlace                             23759 2235.1
# - iDontFeelParticularlyPleasedWithTheWayIAm                       23770 2235.3
# - iAmWellSatisfiedAboutEverythingInMyLife                         23779 2235.5
# - alwaysCalm                                                      23780 2235.5
# - iRarelyWakeUpFeelingRested                                      23780 2235.5
# - extremelyGoodCommunicator                                       23783 2235.6
# - iDontThinkILookAttractive                                       23799 2235.9
# - iUsuallyHaveAGoodInfluenceOnEvents                              23848 2236.9
# - alwaysMakingProgress                                            23865 2237.3
# - alwaysAnxious                                                   23871 2237.4
# - alwaysHaveFun                                                   23879 2237.6
# - doYouFeelASenseOfPurposeAndMeaningInYourLife104                 23900 2238.0
# - alwaysSerious                                                   23903 2238.1
# - iFindMostThingsAmusing                                          23928 2238.6
# - alwaysAccountableAndResponsibleForYourActions                   23953 2239.1
# - iLaughALot                                                      23962 2239.3
# - iAlwaysHaveACheerfulEffectOnOthers                              23970 2239.5
# <none>                                                            23687 2239.8
# - alwaysStressed                                                  24105 2242.3
# - iAmAlwaysCommittedAndInvolved                                   24147 2243.2
# + howOftenDoYouFeelSociallyConnectedWithYourPeersAndFriends       23453 2253.4
# + doYouHaveASupportSystemOfFriendsAndFamilyToTurnToWhenNeeded     23502 2254.5
# + howOftenDoYouParticipateInSocialActivitiesIncludingClubsSportsV 23553 2261.8
# + whatIsYourHeightExpressItAsANumberInMetresM                     22670 2273.8
# - income                                                          66660 2707.4
#
# Step:  AIC=2229.67
# happiness ~ gender + income + doYouFeelASenseOfPurposeAndMeaningInYourLife104 +
#     doYouFeelComfortableEngagingInConversationsWithPeopleFromDiffer +
#     doYouFeelASenseOfPurposeAndMeaningInYourLife105 + alwaysAnxious +
#     alwaysStressed + alwaysAccountableAndResponsibleForYourActions +
#     alwaysCalm + myBodyIsHypermobileAndLovesToMove + alwaysHaveFun +
#     alwaysSerious + alwaysDepressed + alwaysLoveAndCareForYourself +
#     extremelyGoodAbilityToSense + alwaysHaveDigestiveProblems +
#     iAmIntenselyInterestedInOtherPeople + iRarelyWakeUpFeelingRested +
#     iFindMostThingsAmusing + iAmAlwaysCommittedAndInvolved +
#     iDoNotThinkThatTheWorldIsAGoodPlace + iAmWellSatisfiedAboutEverythingInMyLife +
#     iFindBeautyInSomeThings + iAlwaysHaveACheerfulEffectOnOthers +
#     iFeelThatIAmNotEspeciallyInControlOfMyLife + iUsuallyHaveAGoodInfluenceOnEvents +
#     iDontHaveFunWithOtherPeople + alwaysEngageInPreparingAndUsingYourSkillsAndTalentsInOrderToGai +
#     alwaysMakingProgress + extremelyGoodCommunicator + iDontFeelParticularlyPleasedWithTheWayIAm +
#     iFeelThatLifeIsVeryRewarding + iHaveVeryWarmFeelingsTowardsAlmostEveryone +
#     iAmNotParticularlyOptimisticAboutTheFuture + lifeIsGood +
#     iLaughALot + iDontThinkILookAttractive
#
#                                                                   Df Sum of Sq
# - gender                                                           2       189
# - doYouFeelComfortableEngagingInConversationsWithPeopleFromDiffer  3       550
# - iHaveVeryWarmFeelingsTowardsAlmostEveryone                       1         0
# - iAmNotParticularlyOptimisticAboutTheFuture                       1         1
# - iFeelThatLifeIsVeryRewarding                                     1         2
# - myBodyIsHypermobileAndLovesToMove                                1         3
# - iDontHaveFunWithOtherPeople                                      1         4
# - iAmIntenselyInterestedInOtherPeople                              1         8
# - alwaysEngageInPreparingAndUsingYourSkillsAndTalentsInOrderToGai  1         8
# - alwaysHaveDigestiveProblems                                      1         9
# - iFeelThatIAmNotEspeciallyInControlOfMyLife                       1        12
# - alwaysLoveAndCareForYourself                                     1        13
# - lifeIsGood                                                       1        32
# - alwaysDepressed                                                  1        36
# - iFindBeautyInSomeThings                                          1        40
# - doYouFeelASenseOfPurposeAndMeaningInYourLife105                  1        42
# - iDoNotThinkThatTheWorldIsAGoodPlace                              1        52
# - extremelyGoodAbilityToSense                                      1        63
# - alwaysCalm                                                       1        84
# - extremelyGoodCommunicator                                        1        85
# - iDontFeelParticularlyPleasedWithTheWayIAm                        1        93
# - iAmWellSatisfiedAboutEverythingInMyLife                          1        94
# - iRarelyWakeUpFeelingRested                                       1        96
# - iDontThinkILookAttractive                                        1       110
# - iUsuallyHaveAGoodInfluenceOnEvents                               1       148
# - alwaysMakingProgress                                             1       173
# - alwaysAnxious                                                    1       177
# - doYouFeelASenseOfPurposeAndMeaningInYourLife104                  1       204
# - alwaysSerious                                                    1       220
# - alwaysHaveFun                                                    1       234
# - iFindMostThingsAmusing                                           1       239
# - iLaughALot                                                       1       250
# - alwaysAccountableAndResponsibleForYourActions                    1       257
# - iAlwaysHaveACheerfulEffectOnOthers                               1       296
# <none>
# - iAmAlwaysCommittedAndInvolved                                    1       421
# - alwaysStressed                                                   1       464
# + howDoYouReconcileSpiritualBeliefsWithScientificOrRationalThinki  2       110
# + howOftenDoYouFeelSociallyConnectedWithYourPeersAndFriends        3       234
# + doYouHaveASupportSystemOfFriendsAndFamilyToTurnToWhenNeeded      3       151
# + howOftenDoYouParticipateInSocialActivitiesIncludingClubsSportsV  4       140
# + whatIsYourHeightExpressItAsANumberInMetresM                      9      1012
# - income                                                           8     42999
#                                                                     RSS    AIC
# - gender                                                          23987 2221.2
# - doYouFeelComfortableEngagingInConversationsWithPeopleFromDiffer 24348 2222.4
# - iHaveVeryWarmFeelingsTowardsAlmostEveryone                      23798 2223.5
# - iAmNotParticularlyOptimisticAboutTheFuture                      23798 2223.5
# - iFeelThatLifeIsVeryRewarding                                    23799 2223.5
# - myBodyIsHypermobileAndLovesToMove                               23801 2223.5
# - iDontHaveFunWithOtherPeople                                     23802 2223.5
# - iAmIntenselyInterestedInOtherPeople                             23805 2223.6
# - alwaysEngageInPreparingAndUsingYourSkillsAndTalentsInOrderToGai 23806 2223.6
# - alwaysHaveDigestiveProblems                                     23807 2223.7
# - iFeelThatIAmNotEspeciallyInControlOfMyLife                      23810 2223.7
# - alwaysLoveAndCareForYourself                                    23811 2223.7
# ...
# + alwaysMakingProgress                                            26325 2093.7
# + iFeelThatLifeIsVeryRewarding                                    26354 2094.2
# + iDontThinkILookAttractive                                       26360 2094.3
# + iAmNotParticularlyOptimisticAboutTheFuture                      26361 2094.4
# + iHaveVeryWarmFeelingsTowardsAlmostEveryone                      26362 2094.4
# + iAmIntenselyInterestedInOtherPeople                             26362 2094.4
# + alwaysEngageInPreparingAndUsingYourSkillsAndTalentsInOrderToGai 26373 2094.6
# + alwaysLoveAndCareForYourself                                    26376 2094.7
# + extremelyGoodAbilityToSense                                     26376 2094.7
# + myBodyIsHypermobileAndLovesToMove                               26379 2094.7
# + alwaysHaveDigestiveProblems                                     26379 2094.7
# + gender                                                          26174 2097.0
# + howDoYouReconcileSpiritualBeliefsWithScientificOrRationalThinki 26328 2100.0
# + doYouFeelComfortableEngagingInConversationsWithPeopleFromDiffer 26010 2100.1
# + howOftenDoYouFeelSociallyConnectedWithYourPeersAndFriends       26033 2100.6
# + doYouHaveASupportSystemOfFriendsAndFamilyToTurnToWhenNeeded     26231 2104.3
# - alwaysStressed                                                  27797 2108.5
# + howOftenDoYouParticipateInSocialActivitiesIncludingClubsSportsV 26273 2111.4
# + whatIsYourHeightExpressItAsANumberInMetresM                     24878 2115.1
# - income                                                          81145 2600.6
#
# Step:  AIC=2085.46
# happiness ~ income + alwaysStressed + alwaysHaveFun + alwaysSerious +
#     alwaysDepressed + iFindMostThingsAmusing + iAlwaysHaveACheerfulEffectOnOthers +
#     iUsuallyHaveAGoodInfluenceOnEvents
#
#                                                                   Df Sum of Sq
# - iAlwaysHaveACheerfulEffectOnOthers                               1       320
# - alwaysSerious                                                    1       321
# <none>
# - alwaysDepressed                                                  1       345
# - iUsuallyHaveAGoodInfluenceOnEvents                               1       370
# - alwaysHaveFun                                                    1       435
# + iRarelyWakeUpFeelingRested                                       1       191
# - iFindMostThingsAmusing                                           1       489
# + iAmAlwaysCommittedAndInvolved                                    1       168
# + lifeIsGood                                                       1       150
# + doYouFeelASenseOfPurposeAndMeaningInYourLife104                  1       150
# + iDontFeelParticularlyPleasedWithTheWayIAm                        1       143
# + alwaysAnxious                                                    1       142
# + iFeelThatIAmNotEspeciallyInControlOfMyLife                       1       137
# + iAmWellSatisfiedAboutEverythingInMyLife                          1       137
# + iLaughALot                                                       1       128
# + iFindBeautyInSomeThings                                          1       117
# + iDontHaveFunWithOtherPeople                                      1       113
# + extremelyGoodCommunicator                                        1       102
# + alwaysMakingProgress                                             1        85
# + iDoNotThinkThatTheWorldIsAGoodPlace                              1        78
# + alwaysCalm                                                       1        66
# + doYouFeelASenseOfPurposeAndMeaningInYourLife105                  1        49
# + alwaysAccountableAndResponsibleForYourActions                    1        36
# + iAmIntenselyInterestedInOtherPeople                              1        27
# + iDontThinkILookAttractive                                        1        16
# + iFeelThatLifeIsVeryRewarding                                     1         4
# + extremelyGoodAbilityToSense                                      1         4
# + iAmNotParticularlyOptimisticAboutTheFuture                       1         3
# + iHaveVeryWarmFeelingsTowardsAlmostEveryone                       1         3
# + myBodyIsHypermobileAndLovesToMove                                1         2
# + alwaysLoveAndCareForYourself                                     1         0
# + alwaysHaveDigestiveProblems                                      1         0
# + alwaysEngageInPreparingAndUsingYourSkillsAndTalentsInOrderToGai  1         0
# + gender                                                           2       226
# + howDoYouReconcileSpiritualBeliefsWithScientificOrRationalThinki  2        33
# + doYouFeelComfortableEngagingInConversationsWithPeopleFromDiffer  3       306
# + howOftenDoYouFeelSociallyConnectedWithYourPeersAndFriends        3       298
# + doYouHaveASupportSystemOfFriendsAndFamilyToTurnToWhenNeeded      3       179
# - alwaysStressed                                                   1      1612
# + howOftenDoYouParticipateInSocialActivitiesIncludingClubsSportsV  4        71
# + whatIsYourHeightExpressItAsANumberInMetresM                      9      1579
# - income                                                           8     54602
#                                                                     RSS    AIC
# - iAlwaysHaveACheerfulEffectOnOthers                              26867 2085.2
# - alwaysSerious                                                   26868 2085.2
# <none>                                                            26547 2085.5
# - alwaysDepressed                                                 26892 2085.7
# - iUsuallyHaveAGoodInfluenceOnEvents                              26917 2086.2
# - alwaysHaveFun                                                   26982 2087.4
# + iRarelyWakeUpFeelingRested                                      26356 2088.1
# - iFindMostThingsAmusing                                          27036 2088.4
# + iAmAlwaysCommittedAndInvolved                                   26379 2088.5
# + lifeIsGood                                                      26397 2088.8
# + doYouFeelASenseOfPurposeAndMeaningInYourLife104                 26397 2088.8
# + iDontFeelParticularlyPleasedWithTheWayIAm                       26404 2089.0
# + alwaysAnxious                                                   26405 2089.0
# + iFeelThatIAmNotEspeciallyInControlOfMyLife                      26410 2089.1
# + iAmWellSatisfiedAboutEverythingInMyLife                         26410 2089.1
# + iLaughALot                                                      26419 2089.3
# + iFindBeautyInSomeThings                                         26430 2089.5
# + iDontHaveFunWithOtherPeople                                     26434 2089.6
# + extremelyGoodCommunicator                                       26445 2089.8
# + alwaysMakingProgress                                            26462 2090.1
# + iDoNotThinkThatTheWorldIsAGoodPlace                             26469 2090.2
# + alwaysCalm                                                      26481 2090.4
# + doYouFeelASenseOfPurposeAndMeaningInYourLife105                 26498 2090.8
# + alwaysAccountableAndResponsibleForYourActions                   26511 2091.0
# + iAmIntenselyInterestedInOtherPeople                             26520 2091.2
# + iDontThinkILookAttractive                                       26531 2091.4
# + iFeelThatLifeIsVeryRewarding                                    26543 2091.6
# + extremelyGoodAbilityToSense                                     26543 2091.6
# + iAmNotParticularlyOptimisticAboutTheFuture                      26544 2091.6
# + iHaveVeryWarmFeelingsTowardsAlmostEveryone                      26544 2091.6
# + myBodyIsHypermobileAndLovesToMove                               26545 2091.7
# + alwaysLoveAndCareForYourself                                    26547 2091.7
# + alwaysHaveDigestiveProblems                                     26547 2091.7
# + alwaysEngageInPreparingAndUsingYourSkillsAndTalentsInOrderToGai 26547 2091.7
# + gender                                                          26321 2093.6
# + howDoYouReconcileSpiritualBeliefsWithScientificOrRationalThinki 26514 2097.3
# + doYouFeelComfortableEngagingInConversationsWithPeopleFromDiffer 26241 2098.3
# + howOftenDoYouFeelSociallyConnectedWithYourPeersAndFriends       26249 2098.5
# + doYouHaveASupportSystemOfFriendsAndFamilyToTurnToWhenNeeded     26368 2100.7
# - alwaysStressed                                                  28159 2108.7
# + howOftenDoYouParticipateInSocialActivitiesIncludingClubsSportsV 26476 2109.0
# + whatIsYourHeightExpressItAsANumberInMetresM                     24968 2110.7
# - income                                                          81148 2594.4
#
# Step:  AIC=2085.24
# happiness ~ income + alwaysStressed + alwaysHaveFun + alwaysSerious +
#     alwaysDepressed + iFindMostThingsAmusing + iUsuallyHaveAGoodInfluenceOnEvents
#
#                                                                   Df Sum of Sq
# <none>
# - alwaysDepressed                                                  1       339
# + iAlwaysHaveACheerfulEffectOnOthers                               1       320
# - alwaysSerious                                                    1       359
# + iLaughALot                                                       1       230
# + iFeelThatIAmNotEspeciallyInControlOfMyLife                       1       190
# + iDontFeelParticularlyPleasedWithTheWayIAm                        1       174
# + iAmWellSatisfiedAboutEverythingInMyLife                          1       172
# + iRarelyWakeUpFeelingRested                                       1       172
# + lifeIsGood                                                       1       159
# + iDontHaveFunWithOtherPeople                                      1       147
# + doYouFeelASenseOfPurposeAndMeaningInYourLife104                  1       145
# + iFindBeautyInSomeThings                                          1       144
# - alwaysHaveFun                                                    1       539
# + alwaysAnxious                                                    1       133
# + iDoNotThinkThatTheWorldIsAGoodPlace                              1       112
# + iAmAlwaysCommittedAndInvolved                                    1        90
# + alwaysMakingProgress                                             1        74
# + alwaysCalm                                                       1        68
# - iFindMostThingsAmusing                                           1       612
# + doYouFeelASenseOfPurposeAndMeaningInYourLife105                  1        60
# + alwaysAccountableAndResponsibleForYourActions                    1        51
# + extremelyGoodCommunicator                                        1        24
# + iHaveVeryWarmFeelingsTowardsAlmostEveryone                       1        19
# - iUsuallyHaveAGoodInfluenceOnEvents                               1       659
# + iAmIntenselyInterestedInOtherPeople                              1         9
# + iFeelThatLifeIsVeryRewarding                                     1         9
# + myBodyIsHypermobileAndLovesToMove                                1         4
# + iAmNotParticularlyOptimisticAboutTheFuture                       1         4
# + iDontThinkILookAttractive                                        1         3
# + alwaysEngageInPreparingAndUsingYourSkillsAndTalentsInOrderToGai  1         2
# + extremelyGoodAbilityToSense                                      1         2
# + alwaysLoveAndCareForYourself                                     1         1
# + alwaysHaveDigestiveProblems                                      1         0
# + gender                                                           2       225
# + howDoYouReconcileSpiritualBeliefsWithScientificOrRationalThinki  2        43
# + doYouFeelComfortableEngagingInConversationsWithPeopleFromDiffer  3       328
# + howOftenDoYouFeelSociallyConnectedWithYourPeersAndFriends        3       280
# + doYouHaveASupportSystemOfFriendsAndFamilyToTurnToWhenNeeded      3       189
# + howOftenDoYouParticipateInSocialActivitiesIncludingClubsSportsV  4        53
# - alwaysStressed                                                   1      1741
# + whatIsYourHeightExpressItAsANumberInMetresM                      9      1451
# - income                                                           8     54363
#                                                                     RSS    AIC
# <none>                                                            26867 2085.2
# - alwaysDepressed                                                 27205 2085.3
# + iAlwaysHaveACheerfulEffectOnOthers                              26547 2085.5
# - alwaysSerious                                                   27226 2085.7
# + iLaughALot                                                      26637 2087.2
# + iFeelThatIAmNotEspeciallyInControlOfMyLife                      26677 2087.9
# + iDontFeelParticularlyPleasedWithTheWayIAm                       26693 2088.2
# + iAmWellSatisfiedAboutEverythingInMyLife                         26694 2088.2
# + iRarelyWakeUpFeelingRested                                      26695 2088.2
# + lifeIsGood                                                      26708 2088.5
# + iDontHaveFunWithOtherPeople                                     26719 2088.7
# + doYouFeelASenseOfPurposeAndMeaningInYourLife104                 26722 2088.8
# + iFindBeautyInSomeThings                                         26723 2088.8
# - alwaysHaveFun                                                   27406 2088.9
# + alwaysAnxious                                                   26734 2089.0
# + iDoNotThinkThatTheWorldIsAGoodPlace                             26755 2089.4
# + iAmAlwaysCommittedAndInvolved                                   26776 2089.8
# + alwaysMakingProgress                                            26792 2090.1
# + alwaysCalm                                                      26798 2090.2
# - iFindMostThingsAmusing                                          27479 2090.3
# + doYouFeelASenseOfPurposeAndMeaningInYourLife105                 26807 2090.3
# + alwaysAccountableAndResponsibleForYourActions                   26815 2090.5
# + extremelyGoodCommunicator                                       26843 2091.0
# + iHaveVeryWarmFeelingsTowardsAlmostEveryone                      26848 2091.1
# - iUsuallyHaveAGoodInfluenceOnEvents                              27525 2091.1
# + iAmIntenselyInterestedInOtherPeople                             26857 2091.3
# + iFeelThatLifeIsVeryRewarding                                    26858 2091.3
# + myBodyIsHypermobileAndLovesToMove                               26863 2091.4
# + iAmNotParticularlyOptimisticAboutTheFuture                      26863 2091.4
# + iDontThinkILookAttractive                                       26863 2091.4
# + alwaysEngageInPreparingAndUsingYourSkillsAndTalentsInOrderToGai 26864 2091.4
# + extremelyGoodAbilityToSense                                     26865 2091.4
# + alwaysLoveAndCareForYourself                                    26866 2091.4
# + alwaysHaveDigestiveProblems                                     26867 2091.4
# + gender                                                          26642 2093.5
# + howDoYouReconcileSpiritualBeliefsWithScientificOrRationalThinki 26824 2096.9
# + doYouFeelComfortableEngagingInConversationsWithPeopleFromDiffer 26539 2097.7
# + howOftenDoYouFeelSociallyConnectedWithYourPeersAndFriends       26587 2098.7
# + doYouHaveASupportSystemOfFriendsAndFamilyToTurnToWhenNeeded     26677 2100.3
# + howOftenDoYouParticipateInSocialActivitiesIncludingClubsSportsV 26814 2109.1
# - alwaysStressed                                                  28607 2110.4
# + whatIsYourHeightExpressItAsANumberInMetresM                     25415 2113.4
# - income                                                          81229 2588.7
# [1] "Root Mean Squared Error (rMSE) of Stepwise Model: 7.33030486894785"

# %% [markdown]
# The fact that the rMSE of the stepwise model (7.33) is higher than that of the original full model (6.67) is somewhat unusual. Generally, stepwise regression aims to simplify the model by retaining significant predictors and removing redundant ones, potentially improving the model's performance. However, this higher rMSE indicates that the full model's complexity was necessary to capture important relationships within the data.

# %% [markdown]
# ## Question 4 (2 Mark)
# Although stepwise regression has reduced the model complexity significantly, the model still contains a lot of variables that we want to remove. Therefore, you are interested in lightweight linear regression models with ONLY TWO predictors. Write a script to automatically find the best lightweight model which corresponds to the model with the least **rMSE** on the training dataset. Compare the **rMSE** of the best lightweight model with the **rMSE** of the full model - ```lm.fit``` - that you built previously. Give an explanation for these results based on consideration of the predictors involved.

# %%
# ANSWER BLOCK
# Convert categorical variables to factors
for (col in colnames(train_df)) {
  if (is.character(train_df[[col]])) {
    train_df[[col]] <- as.factor(train_df[[col]])
  }
}

# Find the best lightweight model with only two predictors
best_rmse <- Inf
best_model <- NULL
best_predictors <- NULL

predictors <- colnames(train_df)[colnames(train_df) != "happiness"]

for (i in 1:(length(predictors) - 1)) {
  for (j in (i + 1):length(predictors)) {
    formula <- as.formula(paste("happiness ~", predictors[i], "+", predictors[j]))
    model <- lm(formula, data = train_df)
    predictions <- predict(model, newdata = train_df)
    rmse <- calculate_rmse(train_df$happiness, predictions)
    
    if (rmse < best_rmse) {
      best_rmse <- rmse
      best_model <- model
      best_predictors <- c(predictors[i], predictors[j])
    }
  }
}

# Print the results
print(paste("Best lightweight model predictors:", paste(best_predictors, collapse = " + ")))
print(paste("Root Mean Squared Error (rMSE) of Best Lightweight Model:", best_rmse))
print(paste("Root Mean Squared Error (rMSE) of Full Model:", rmse_full_model))
# Out:
# [1] "Best lightweight model predictors: income + alwaysStressed"
# [1] "Root Mean Squared Error (rMSE) of Best Lightweight Model: 7.88541130213321"
# [1] "Root Mean Squared Error (rMSE) of Full Model: 6.67255660795814"

# %% [markdown]
# ### ANSWER (TEXT)
# The results indicate that the best lightweight model, which includes only the predictors "income" and "alwaysStressed," has a higher root mean squared error (rMSE) of approximately 7.89 compared to the full model's rMSE of approximately 6.67.
# The lightweight model with only two predictors, "income" and "alwaysStressed," is simpler but less accurate than the full model. This higher rMSE in the lightweight model indicates that other predictors in the full model are contributing significantly to the prediction of happiness. The full model's ability to incorporate more variables allows it to better capture the complexities and interactions within the data, resulting in more accurate predictions.

# %% [markdown]
# ## Question 5 (Libraries are allowed) (40 Marks)
# As a Data Scientist, one of the key tasks is to build models $\textbf{most appropriate/closest}$ to the truth; thus, modelling will not be limited to the aforementioned steps in this assignment. To simulate for a realistic modelling process, this question will be in the form of a [Kaggle competition](https://www.kaggle.com/t/ad8c96e412254c138cbec1d9d1c09734) among students to find out who has the best model.
#
# Thus, you **will be graded** by the **rMSE** performance of your model, the better your model, the higher your score. Additionally, you need to describe/document your thought process in this model building process, this is akin to showing your working properly for the mathematic sections. If you don't clearly document the reasonings behind the model you use, we will have to make some deductions on your scores.
#
# This is the [video tutorial](https://www.youtube.com/watch?v=rkXc25Uvyl4) on how to join any Kaggle competition.
#
# When you optimize your model's performance, you can use any supervised model that you know and feature selection might be a big help as well. [Check the non-exhaustive set of R functions relevant to this unit](https://learning.monash.edu/mod/resource/view.php?id=2017193) for ideas for different models to try.
#
# $\textbf{Note}$ Please make sure that we can install the libraries that you use in this part, the code structure can be:
#
# ```install.packages("some package", repos='http://cran.us.r-project.org')```
#
# ```library("some package")```
#
# Remember that if we cannot run your code, we will have to give you a deduction. Our suggestion is for you to use the standard ```R version 3.6.1```
#
# You also need to name your final model ``fin.mod`` so we can run a check to find out your performance. A good test for your understanding would be to set the previous $\textbf{BIC model}$ to be the final model to check if your code works perfectly.

# %%
# Function to check and install packages if not already installed
install_if_missing <- function(packages) {
  for (package in packages) {
    if (!require(package, character.only = TRUE)) {
      install.packages(package, repos = 'http://cran.us.r-project.org')
      library(package, character.only = TRUE)
    }
  }
}

# List of required packages
required_packages <- c("caret", "xgboost", "randomForest", "e1071")

# Install missing packages
install_if_missing(required_packages)

# %%
# Load required libraries
library(caret)
library(xgboost)
library(randomForest)
library(e1071)

# %%
# Load the data
train_df <- read.csv("regression_train.csv")

# Handle missing values by imputing with the median
preProcValues <- preProcess(train_df, method = c("medianImpute", "zv"))

# Ensure no missing values after preprocessing
train_df <- na.omit(train_df)

# Convert 'happiness' column to numeric if necessary
train_df$happiness <- as.numeric(train_df$happiness)

# Define the training control with 5-fold cross-validation
train_control <- trainControl(
  method = "cv", 
  number = 5,
  savePredictions = "final",
  allowParallel = TRUE
)

# Train the Random Forest model with the best parameters
set.seed(100)
rf_model <- train(
  happiness ~ ., 
  data = train_df, 
  method = "rf", 
  trControl = train_control, 
  tuneGrid = expand.grid(mtry = 12),
  ntree = 500  # Set ntree directly here
)

# Train the SVM model with the best parameters
set.seed(100)
svm_model <- train(
  happiness ~ ., 
  data = train_df, 
  method = "svmRadial", 
  trControl = train_control, 
  tuneGrid = expand.grid(C = 5, sigma = 0.005)
)

# Define the best parameters for xgbTree
best_params <- expand.grid(
  nrounds = 500,
  max_depth = 3,
  eta = 0.05,
  gamma = 0.5,
  colsample_bytree = 0.5,
  min_child_weight = 5,
  subsample = 0.9
)

# Train the XGBoost model with the best parameters
set.seed(100)
xgb_model <- train(
  happiness ~ ., 
  data = train_df, 
  method = "xgbTree", 
  trControl = train_control, 
  tuneGrid = best_params, 
  nthread = 1,
  verbosity = 1
)

# Combine predictions from the individual models
pred_train <- data.frame(
  xgb = predict(xgb_model, newdata = train_df),
  rf = predict(rf_model, newdata = train_df),
  svm = predict(svm_model, newdata = train_df),
  happiness = train_df$happiness
)

# %%
# Build your final model here, use additional coding blocks if you need to
set.seed(100)
fin.mod <- train(
  happiness ~ ., 
  data = pred_train, 
  method = "lm", 
  trControl = trainControl(method = "cv", number = 5)
)

# %%
# Load in the test data.
test <- read.csv("regression_test.csv")
# Handle missing values by imputing with the median
test <- predict(preProcValues, test)
# Ensure no missing values after preprocessing
test <- na.omit(test)
# Make predictions on the test set
pred_test <- data.frame(
  xgb = predict(xgb_model, newdata = test),
  rf = predict(rf_model, newdata = test),
  svm = predict(svm_model, newdata = test)
)
# If you are using any packages that perform the prediction differently, please change this line of code accordingly.
pred.label <- predict(fin.mod, newdata = pred_test)
# put these predicted labels in a csv file that you can use to commit to the Kaggle Leaderboard
write.csv(
  data.frame("RowIndex" = seq(1, length(pred.label)), "Prediction" = pred.label),  
  "RegressionPredictLabel.csv", 
  row.names = FALSE
)

# %%
## PLEASE DO NOT ALTER THIS CODE BLOCK, YOU ARE REQUIRED TO HAVE THIS CODE BLOCK IN YOUR JUPYTER NOTEBOOK SUBMISSION
## Please skip (don't run) this if you are a student
## For teaching team use only

tryCatch(
    {
        source("../supplimentary.R")
    },
    error = function(e){
        source("supplimentary.R")
    }
)

truths <- tryCatch(
    {
        read.csv("../regression_test_label.csv")
    },
    error = function(e){
        read.csv("regression_test_label.csv")
    }
)


RMSE.fin <- rmse(pred.label, truths$x)
cat(paste("RMSE is", RMSE.fin))

# %% [markdown]
# # Part 2 Classification (50 Marks)

# %% [markdown]
# A few thousand people were questioned in a [life and wellbeing survey](https://www.get-happier.com/) to build a model to predict happiness of an individual, but this time we want to predict a categorical score for perfect mental health, rather than a continuous score. You need to build 5-class classification models to optimally predict the variable in the survey dataset called 'perfectMentalHealth' based on any, or all, of the other survey question responses.
#
# You have been provided with two datasets, ```classification_train.csv``` and ```classification_test.csv```. Using these datasets, you hope to build a model that can predict 'perfectMentalHealth' using the other variables. ```classification_train.csv``` comes with the ground-truth target label (i.e. 'perfectMentalHealth' happiness classes) whereas `classification_test.csv` comes with independent variables (input information) only.
#
# On the order of around 70 survey questions have been converted into predictor variables that can be used to predict 'perfectMentalHealth'. We do not list all the predictor names here, but their names given in the data header can clearly be linked to the survey questions. E.g. the predictor variable 'iDontFeelParticularlyPleasedWithTheWayIAm' corresponds to the survey question 'I don’t feel particularly pleased with the way I am.'
#
# This question will also be in the form of a [Kaggle competition](https://www.kaggle.com/t/968d3b346acb47779771f47785c39e62) among students to find out who has the best model.

# %%
# Function to check and install packages if not already installed
install_if_missing <- function(packages) {
  for (package in packages) {
    if (!require(package, character.only = TRUE)) {
      install.packages(package, repos = 'http://cran.us.r-project.org')
      library(package, character.only = TRUE)
    }
  }
}

# List of required packages
required_packages <- c("readr", "dplyr", "xgboost", "caret")

# Install missing packages
install_if_missing(required_packages)

# %%
# Load necessary libraries
library(readr)
library(dplyr)
library(xgboost)
library(caret)

# %%
# Load in the train and test classification data.
train <- read.csv('classification_train.csv')
test <- read.csv('classification_test.csv')

# Function to encode ordinal and binary encode specific columns
encode_data <- function(data, columns_levels, binary_columns) {
  # Ordinal encoding for specified columns
  for (col in names(columns_levels)) {
    levels <- columns_levels[[col]]
    data[[col]] <- factor(data[[col]], levels = levels, ordered = TRUE)
    data[[col]] <- as.numeric(data[[col]])  # Convert factor to numeric
  }
  
  # Binary encoding for yes/no and gender columns
  for (col in binary_columns) {
    data[[col]] <- ifelse(data[[col]] == "Yes" | data[[col]] == "Female", 1, 0)
  }
  
  # Convert all columns to numeric, handling NAs
  data <- data.frame(lapply(data, function(x) {
    x <- as.numeric(as.character(x))
    x[is.na(x)] <- -999  # Replace NA values with a placeholder
    return(x)
  }))
  
  return(data)
}

# Update levels for each ordinal column to include all unique values
columns_levels <- list(
  income = c("0 - 10k", "10k - 15k", "15k - 20k", "20k - 50k", 
             "50k - 80k", "80k - 120k", "120k - 150k", "150k - 200k", "200k above"),
  whatIsYourHeightExpressItAsANumberInMetresM = c("140 - 150", "150 - 155", "155 - 160", "160 - 165", "165 - 170", 
                                                  "170 - 175", "175 - 180", "180 - 185", "185 - 190", "190 above"),
  howDoYouReconcileSpiritualBeliefsWithScientificOrRationalThinki = c("They are separate", "They complement each other", "They conflict"),
  howOftenDoYouFeelSociallyConnectedWithYourPeersAndFriends = c("Never", "Rarely", "Sometimes", "Often", "Always"),
  doYouHaveASupportSystemOfFriendsAndFamilyToTurnToWhenNeeded = c("No", "Yes, I have both", "Yes, I have family", "Yes, I have friends"),
  howOftenDoYouParticipateInSocialActivitiesIncludingClubsSportsV = c("No", "Rarely", "At least once a month", "At least once a week", "More than three times a week"),
  doYouFeelComfortableEngagingInConversationsWithPeopleFromDiffer = c("Never", "Rarely", "Sometimes", "Always")
)

# Define binary columns
binary_columns <- c("doYouFeelASenseOfPurposeAndMeaningInYourLife104", 
                    "doYouFeelASenseOfPurposeAndMeaningInYourLife105",
                    "gender")

# Encode the data
train_data_encoded <- encode_data(train_data, columns_levels, binary_columns)
test_data_encoded <- encode_data(test_data, columns_levels, binary_columns)

# Select top features after performing Recursive Feature Elimination
top_features <- c("alwaysLoveAndCareForYourself", "lifeIsGood", 
                  "alwaysEngageInPreparingAndUsingYourSkillsAndTalentsInOrderToGai", 
                  "alwaysCalm", "alwaysStressed")

# Subset the data to include only the top features
train_data_top_features <- train_data_encoded %>% select(all_of(top_features))
test_data_top_features <- test_data_encoded %>% select(all_of(top_features))

# Convert original labels to a 0-based index
unique_labels <- sort(unique(train_data$perfectMentalHealth))
label_mapping <- setNames(seq_along(unique_labels) - 1, unique_labels)
train_labels <- as.numeric(label_mapping[as.character(train_data$perfectMentalHealth)])
test_labels <- as.numeric(label_mapping[as.character(test_data$perfectMentalHealth)])
num_classes <- length(unique_labels)

# Define the best parameters for XGBoost after model tuning
best_params <- list(
  objective = "multi:softmax",
  eval_metric = "merror",
  num_class = num_classes,
  max_depth = 5,
  min_child_weight = 0.8,
  gamma = 0.1,
  subsample = 0.7,
  colsample_bytree = 0.6,
  eta = 0.01
)

set.seed(123)

# Prepare data for XGBoost
dtrain <- xgb.DMatrix(data = as.matrix(train_data_top_features), label = train_labels)
dtest <- xgb.DMatrix(data = as.matrix(test_data_top_features))

# %%
# Build your final model here, use additional coding blocks if you need to
fin.mod <- xgb.train(params = best_params, data = dtrain, nrounds = 1000)

# If you are using any packages that perform the prediction differently, please change this line of code accordingly.
pred_indices <- predict(fin.mod, dtest)
pred.label <- unique_labels[pred_indices + 1]  # Map back to original labels

# put these predicted labels in a csv file that you can use to commit to the Kaggle Leaderboard
write.csv(
    data.frame("RowIndex" = seq(1, length(pred.label)), "Prediction" = pred.label),  
    "ClassificationPredictLabel.csv", 
    row.names = F
)

# %%
## PLEASE DO NOT ALTER THIS CODE BLOCK, YOU ARE REQUIRED TO HAVE THIS CODE BLOCK IN YOUR JUPYTER NOTEBOOK SUBMISSION
## Please skip (don't run) this if you are a student
## For teaching team use only

truths <- tryCatch(
    {
        read.csv("../classification_test_label.csv")
    },
    error = function(e){
        read.csv("classification_test_label.csv")
    }
)

f1_score <- F1_Score(truths$x, pred.label)
cat(paste("f1_score is", f1_score))
